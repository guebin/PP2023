# %% [raw]
# ---
# title: "12wk-1: 클래스 (4)"
# author: "최규빈"
# date: "05/24/2023"
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/PP2023/blob/main/posts/03_Class/2023-05-24-12wk-2.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %% [markdown]
# # imports

# %%
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # 클래스공부 3단계: 문제연습

# %% [markdown]
# ## 암기사항

# %% [markdown]
# ***외우세요*** (논리적으로 생각하지 말고)

# %% [markdown]
# `#1` 클래스의 선언: 클래스의 선언은 아래와 같이 하며 클래스의 이름은 대문자로 한다.

# %% [markdown]
# ```Python
# # 예시1: 좋은사례
# class JungKKuckMa:
#     pass
# ```

# %% [markdown]
# ```Python
# # 예시2: 나쁜사례 -- 클래스 이름은 대문자로 시작해야해
# class jungkkuckma:
#     pass
# ```

# %% [markdown]
# > 딴지: 1. 사실 저거 말고도 선언하는 방법 있는데.. 2. 대문자가 아니어도 에러는 안나는데..

# %% [markdown]
# `#2` 클래스의 내용: 클래스의 내용은 메소드만을 정의하는데에만 사용한다.

# %% [markdown]
# ```Python
# # 예시1: 클래스의 내용을 메소드로만 작성한예시
# class JungKKuckMa:
#     def method1(self):
#         blabla
#     def method2(self):
#         blabla
#     def method3(self):
#         blabla
#     def method4(self):
#         blabla
#     def method5(self):
#         blabla
# ```

# %% [markdown]
# ```Python
# # 예시2: 나쁜사례
# class JungKKuckMa:
#     a=1
#     b=1
# ```

# %% [markdown]
# > 딴지: 꼭 메소드만 쓰라는 법은 없지 않나?

# %% [markdown]
# `#3` 메소드의 첫번째 입력은 항상 self 로 사용한다.

# %% [markdown]
# > 딴지: 이것도 꼭 그런건 아님

# %% [markdown]
# `#4` `__init__` 메소드는 "클래스 $\to$ 인스턴스" 시점에 자동으로 실행되는 특수한 메소드이다.

# %% [markdown]
# ## 문제풀이

# %% [markdown]
# ***각 예제의 조건에 맞는 클래스를 구현하라***

# %% [markdown]
# `-` **예제** -- self는 항상 써야 해
#
# 1. 클래스에는 hello()라는 메소드가 정의되어 있으며, hello()의 기능은 "안녕하세요"를 출력하는 것이다.

# %% [markdown]
# `-` **예제**-- `__init__`의 사용방법
#
# 1. "클래스 $\to$ 인스턴스"의 과정에서 변수 a가 True 로 초기설정된다.
# 2. 클래스에는 show()라는 메소드가 정의되어 있으며, show()의 기능은 a의 값을 print 하는 기능을 한다.

# %% [markdown]
# `-` **예제**-- method의 정의 및 사용
#
# 1. "클래스 $\to$ 인스턴스"의 과정에서 변수 a가 True 로 초기설정된다.
# 2. 클래스에는 toggle() 이라는 메소드가 정의되어 있다. 이 기능은 변수 a의 값이 True 이면 False 로, False 이면 True 로 바꾸는 역할을 한다.
# 3. 클래스에는 show()라는 메소드가 정의되어 있다. 이 기능은 a의 값을 print 하는 기능을 한다.

# %% [markdown]
# `-` **예제** -- method의 정의 및 사용
#
# 1. "클래스 $\to$ 인스턴스"의 과정에서 변수 a가 0으로 초기설정된다.
# 2. 클래스에는 up()라는 메소드가 정의되어 있다. up()의 기능은 a의 값을 1증가시키는 기능을 한다.
# 3. 클래스에는 show()라는 메소드가 정의되어 있다. show()의 기능은 a의 값을 print 하는 가능을 한다.

# %% [markdown]
# `-` **예제** -- 외부입력을 사용하는 `__init__`
#
# 1. "클래스 $\to$ 인스턴스"의 과정에서 변수 a의 값이 사용자가 입력한 값으로 초기설정된다.
# 2. 클래스에는 show()라는 메소드가 정의되어 있다. show()의 기능은 a의 값을 print 하는 가능을 한다.

# %% [markdown]
# `-` **예제** -- 외부입력을 사용하는 method
#
# 1. "클래스 $\to$ 인스턴스"의 과정에서 변수 a가 0으로 초기설정된다.
# 2. 클래스에는 up()라는 메소드가 정의되어 있다. up()의 기능은 a의 값을 1증가시키는 기능을 한다.
# 3. 클래스에는 jump()라는 메소드가 정의되어 있다. jump()는 jump_size 를 입력으로 받으며 a의 값을 jump_size 만큼 증가시키는 기능을 한다.
# 4. 클래스에는 show()라는 메소드가 정의되어 있다. show()의 기능은 a의 값을 print 하는 기능을 한다.

# %% [markdown]
# `-` **예제** -- 아래의 조건을 만족하는 클래스를 구현하라.
#
# 1. "클래스 $\to$ 인스턴스"의 과정에서 변수 a가 0으로 초기설정된다.
# 2. 클래스에는 up()라는 메소드가 정의되어 있다. up()의 기능은 a의 값을 1증가시키는 기능을 한다.
# 3. 클래스에는 jump()라는 메소드가 정의되어 있다. jump()는 jump_size 를 입력으로 받으며 a의 값을 jump_size 만큼 증가시키는 기능을 한다.
# 4. 클래스에는 reset()이라는 메소드가 정의되어 있다. reset()는 a의 값을 0으로 초기화하는 역할을 한다.
# 5. 클래스에는 show()라는 메소드가 정의되어 있다. show()의 기능은 a의 값을 print 하는 기능을 한다.

# %% [markdown]
# `-` **예제:** 아래의 조건을 만족하는 클래스를 구현하라.
#
# 1. "클래스 $\to$ 인스턴스"의 과정에서 아래의 변수 url이 `https://mblogthumb-phinf.pstatic.net/MjAyMTA0MjRfNTEg/MDAxNjE5MjMyNDQzMjQ4.nTAVvM-0BTwGCSCMrIAUS8nKX2zr2gwjgBLiRwoYPMMg.NZmjL1mMKCB1KBXyftkLayAnRtLOVn-egCbs-3HMeA0g.JPEG.hotgogimandu/5b57e234fe138983ce18b34db9ea9c4d.jpg?type=w800`의 값으로 초기화된다.

# %% [markdown]
# **hint** 아래의 코드를 관찰

# %%
#import datetime
print(datetime.datetime.now())
# Out:
# 2023-05-24 11:41:20.786074

# %%
class JungKKuckMa: 
    def time(self):
        print(datetime.datetime.now())

# %% [markdown]
# ![image.png](attachment:22363ee7-15dd-420a-baea-4171b6e44aec.png)

# %% [markdown]
# **문제3:** 아래의 클래스를 구현하라.
#
# `-` 클래스내에는 변수 a가 있다. 변수 a의 초기값은 0이다.
#
# `-` 클래스에는 up(),down(),show()라는 메소드가 있다. 각각은 a의 값을 1증가, a의 값을 1감소, a의 값을 print하는 기능을 한다.

# %% [markdown]
# **문제4:** 아래의 클래스를 구현하라.
#
# `-` 클래스내에는 변수 url이 있음. url의 초기값은 `https://github.com/guebin/IP2022/blob/master/_notebooks/2022-05-07-stop1.jpeg?raw=true`이다.
#
# `-` 클래스에는 show()이라는 메소드를 가지는데, 메소드는 아래와 같은 기능을 한다.
# - 기능1: url의 그림을 출력
# - 기능2: '당신은 이 그림을 $n$번 보았습니다' 출력. 여기에서 $n$은 그림을 본 횟수
