# %% [markdown]
# # 01wk-1: 강의소개
#
# 최규빈
# 2023-03-06
#
# # 이 수업을 들어야 하는 이유
#
# 생략
#
# ------------------------------------------------------------------------
#
# # 이 수업을 듣지 말아야 하는 이유
#
# `1`. F학점을 많이 준다.
#
# -   30%까지 F를 줄 수 있음.
# -   F학점은 태도점수+시험성적을 종합하여 부여함 (태도점수로만 부여하지
#     않음)
#
# `2`. 파이썬을 배울 수 있는 다른 대안이 많다.
#
# -   [ChatGPT](https://chat.openai.com)
# -   패스트캠퍼스
# -   학원
# -   각종 캠프
#
# `3`. cost-effective 하지 않음
#
# -   열심히 공부해도 시험성적이 안 좋을 수 있음. $\to$ 학점도 안좋아짐
# -   왜? (1) 타전공 고수들이 많음 (2) 시험문제가 어려움 (3) 기출문제가 별
#     의미없음 (4) 적성에 안 맞음
#
# `4`. 꼭 파이썬을 배워야 할까?
#
# ***이거 꼭 들어야 졸업가능? –\> 파이썬을 못하면 선택의 폭이 좁아지긴
# 하지만 졸업불가능한 정도는 아님***
#
# -   <https://stat.jbnu.ac.kr/stat/6453/subview.do>
#
# ***파이썬 못하면 굶어죽을까? –\> 몇몇 진로에서는 파이썬이 필요함. 그런데
# 다 그런건 아님***
#
# *통계학과 졸업생이 갈 수 있는 진로들*
#
# -   의약계열: 전북대병원, XX병원, XX제약, 셀트리온, 삼성바이오
# -   금융계열: 전북은행, XX은행, XX증권, XX화재
# -   공무원,공기업: 통계청, 9급공무원, 국민연금 등
# -   기타 대기업: 삼성전자 (인사과)…
# -   국책연구기관: 에트리, 한국교통연구원 등
# -   금융공기업: 한국은행, 금융감독원, 한국거래소 등
# -   제조업: 삼성전자, 하이닉스, LG전자, 현대자동차 등 (스마트팩토리)
# -   통신사: SKT, KT, LGU
# -   컨설팅: 베가스, 삼성SDS, LG-CNS 등
# -   게임회사: 엔씨, 넷마블, 위메이드 등
# -   인공지능, 빅데이터: 네이버, 카카오, 라인, 쿠팡, 배민(?), SKT, 삼성,
#     LG, …
# -   순수IT:
#
# ------------------------------------------------------------------------
#
# # 수업진행
#
# -   다음시간부터 개인 노트북 지참
# -   wifi: 218-5G-1. 218-5G-2
# -   가급적 영상 올릴 생각… (복습용도)
# -   질문: 카톡, 이메일, 직접방문, 줌, 등등~
