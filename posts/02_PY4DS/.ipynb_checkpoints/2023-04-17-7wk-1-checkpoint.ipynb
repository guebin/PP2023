# %% [raw]
# ---
# title: "07wk-1: Numpy 활용 (1)"
# author: "최규빈"
# date: "04/17/2023"
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/PP2023/blob/main/posts/02_PY4DS/2023-04-12-7wk-1.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %% [markdown]
# # 강의영상

# %% [markdown]
# > youtube: <https://youtube.com/playlist?list=PLQqh36zP38-ymffyqSCkU7zE4L7VC4Rg7>

# %% [markdown]
# -- 위의 강의영상이 깨짐을 확인하였습니다. (소리만 녹음되고 영상은 멈춰있음) 해당영상은 주말중 재촬영할 예정이니 그때 학습하시기 바랍니다. 학습에 불편을 드려 죄송합니다.

# %% [markdown]
# # import

# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL 
import pandas as pd

# %% [markdown]
# # 예비학습: matplotlib

# %%
# import matplotlib.pyplot as plt

# %% [markdown]
# ## line plot

# %% [markdown]
# ### 기본플랏

# %% [markdown]
# `-` 예시1

# %%
x=[1,2,3,4]
y=[1,2,4,3]

# %%
plt.plot(x,y)

# %% [markdown]
# ### 모양변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'--')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,':')

# %% [markdown]
# `-` 예시3

# %%
plt.plot(x,y,'-.')

# %% [markdown]
# ### 색상변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'r')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,'k')

# %% [markdown]
# ### 모양 + 색상변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'--r')

# %% [markdown]
# `-` 예시2: 순서변경 가능

# %%
plt.plot(x,y,'r--')

# %% [markdown]
# ### 원리? ($\star$)

# %% [markdown]
# `-` `r--`등의 옵션은 Markers + Line Styles + Colors 의 조합으로 표현가능

# %% [markdown]
# ref: <https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html>

# %% [markdown]
# - `--r`: 점선(dashed)스타일 + 빨간색
# - `r--`: 빨간색 + 점선(dashed)스타일
# - `:k`: 점선(dotted)스타일 + 검은색
# - `k:`: 검은색 + 점선(dotted)스타일

# %% [markdown]
# `-` 우선 Marker를 무시하면 Line Styles + Color로 표현가능한 조합은 $4\times 8=32$ 개

# %% [markdown]
# **(Line Styles)** 모두 4개

# %% [markdown]
# | character | description|
# |:-:|:-:|
# | '-' | solid line style |
# | '--' | dashed line style |
# | '-.' | dash-dot line style |
# | ':' | dotted line style|

# %% [markdown]
# **(Color)** 모두 8개

# %% [markdown]
# |character|color|
# |:-:|:-:|
# |'b'| blue|
# |'g'|green|
# |'r'|red|
# |'c'|cyan|
# |'m'|magenta|
# |'y'|yellow|
# |'k'|black|
# |'w'|white|

# %% [markdown]
# ## scatter plot

# %% [markdown]
# ### 기본플랏

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'o')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,'.')

# %% [markdown]
# `-` 예시3

# %%
plt.plot(x,y,'x')

# %% [markdown]
# ### 색깔변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'or')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,'db')

# %% [markdown]
# `-` 예시3

# %%
plt.plot(x,y,'bx')

# %% [markdown]
# ## dot-connected plot

# %% [markdown]
# `-` 예시1: 마커와 라인스타일을 동시에 사용하면 dot-connected plot이 된다.

# %%
plt.plot(x,y,'o-')

# %% [markdown]
# `-` 예시2: 당연히 색도 적용가능함

# %%
plt.plot(x,y,'o--r')

# %% [markdown]
# `-` 예시3: 서로 순서를 바꿔도 상관없다.

# %%
plt.plot(x,y,'ro--')

# %% [markdown]
# ## 겹쳐그리기

# %% [markdown]
# `-` 예시1

# %%
x = np.arange(-5,5,0.1)
ϵ = np.random.randn(100) 
y = 2*x + ϵ

# %%
plt.plot(x,y,'.')
plt.plot(x,2*x,'--')

# %% [markdown]
# # 넘파이 활용 (1단계)

# %% [markdown]
# ## 그래프

# %% [markdown]
# `1`. $y(t)=\cos(2t)$와 $x(t)=\sin(t)$를 고려하자. $y(t)=x(t)$는 $-3.14\leq t \leq 3.14$ 에서 몇 개의 해를 가지는가? 그래프를 통하여 확인하라.

# %% [markdown]
# (풀이)

# %%
t = np.linspace(-3.14,3.14,1000) 
x = np.sin(t)
y = np.cos(2*t)
plt.plot(t,x)
plt.plot(t,y)

# %% [markdown]
# `2-3`. 아래와 같은 합성함수를 생각하라.
#
# - $l(x)=w_0+w_1x$
# - $a(x)=\frac{1}{1+e^{-x}}$

# %% [markdown]
# `2`. $x \in [-5,5]$의 범위에서 $a(l(x))$의 그래프를 그려라. 단 이때 $w_0=0, w_1=1$로 설정한다.

# %% [markdown]
# (풀이)

# %%
def l(w0,w1,x): 
    return w0+w1*x 
def a(x):
    return 1/(1+np.exp(-x))

# %%
x = np.linspace(-5,5,100)
plt.plot(x,a(l(0,1,x)))
plt.plot(x,a(l(0,5,x)))
plt.plot(x,a(l(3,-3,x)))

# %% [markdown]
# `3`. 아래는 $a(l(x))$의 성질에 대하여 토의한 내용이다. 올바르게 서술한 학생을 골라라.
#
# - 하영: $w_1>0$ 이라면 $a(l(x))$는 증가하는 함수이다.
# - 재인:
# - 서연:
# - 보람:
# - 지윤:

# %% [markdown]
# ## 자료를 저장하는 행렬

# %% [markdown]
# `1-2`. 아래와 같은 자료를 관측하였다고 하자.

# %%
X = np.array([[11.75 ,  5.72 ],
              [12.39 ,  7.695],
              [11.75 ,  6.93 ],
              [11.625,  4.195],
              [12.6  ,  6.734],
              [11.13 ,  6.688],
              [12.24 ,  7.33 ],
              [13.586,  1.072],
              [10.9  ,  4.125],
              [10.68 ,  3.691]])

# %% [markdown]
# `1`. X를 평균과 표준편차를 columnwise 하게 구하라. 즉 1열의 평균, 2열의 평균, 1열의 표준편차, 2열의 표준편차를 구하라.
#
# **note:** 표준편차는 `ddof=1`과 함께 `np.std()`를 사용할 것

# %% [markdown]
# (풀이)

# %%
X.mean(axis=0)
# Out:
# array([11.8651,  5.418 ])

# %%
X.std(ddof=1,axis=0)
# Out:
# array([0.87420064, 2.09762829])

# %% [markdown]
# `2`. X를 columnwise 하게 표준화하라.

# %% [markdown]
# **hint:** 아래의 함수를 관찰하고 이용

# %% [markdown]
# (예시1)

# %%
X.sum(axis=0)
# Out:
# array([118.651,  54.18 ])

# %%
X.sum(axis=0), np.apply_along_axis(np.sum,axis=0,arr=X)
# Out:
# (array([118.651,  54.18 ]), array([118.651,  54.18 ]))

# %% [markdown]
# (예시2)

# %%
def f(arr):
    return arr - np.min(arr) 
X, np.apply_along_axis(f,axis=0,arr=X)
# Out:
# (array([[11.75 ,  5.72 ],
#         [12.39 ,  7.695],
#         [11.75 ,  6.93 ],
#         [11.625,  4.195],
#         [12.6  ,  6.734],
#         [11.13 ,  6.688],
#         [12.24 ,  7.33 ],
#         [13.586,  1.072],
#         [10.9  ,  4.125],
#         [10.68 ,  3.691]]),
#  array([[1.07 , 4.648],
#         [1.71 , 6.623],
#         [1.07 , 5.858],
#         [0.945, 3.123],
#         [1.92 , 5.662],
#         [0.45 , 5.616],
#         [1.56 , 6.258],
#         [2.906, 0.   ],
#         [0.22 , 3.053],
#         [0.   , 2.619]]))

# %% [markdown]
# (풀이)

# %%
def f(x):
    return (x- np.mean(x))/ np.std(x,ddof=1)

# %%
np.apply_along_axis(f,axis=0,arr=X)
# Out:
# array([[-0.13166314,  0.14397212],
#        [ 0.60043424,  1.08551168],
#        [-0.13166314,  0.72081408],
#        [-0.27465091, -0.58303943],
#        [ 0.84065369,  0.62737522],
#        [-0.84088247,  0.60544569],
#        [ 0.42884892,  0.91150563],
#        [ 1.96854122, -2.07186374],
#        [-1.10397997, -0.61641045],
#        [-1.35563844, -0.82331079]])

# %% [markdown]
# `3-5`. 아래는 이미지파일을 불러오는 코드이다.

# %%
# import PIL

# %%
# !wget https://raw.githubusercontent.com/guebin/SC2022/main/hani.jpeg
hani = np.einsum('ijk->jik',np.array(PIL.Image.open('hani.jpeg'),dtype=np.int64)/255)
# !rm hani.jpeg
# Out:
# --2023-04-17 14:59:01--  https://raw.githubusercontent.com/guebin/SC2022/main/hani.jpeg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2445959 (2.3M) [image/jpeg]
# Saving to: ‘hani.jpeg’
#
# hani.jpeg           100%[===================>]   2.33M  --.-KB/s    in 0.04s
#
# 2023-04-17 14:59:01 (57.0 MB/s) - ‘hani.jpeg’ saved [2445959/2445959]

# %% [markdown]
# - note: 위 코드는 코랩 혹은 리눅스기반 환경에서 동작가능.
# - 주피터노트북의 경우 아래의 절차를 따를 것
#
#     1. <https://raw.githubusercontent.com/guebin/SC2022/main/hani.jpeg> 에서 직접사진을 다운로드
#     2. 현재작업중인 주피터노트북과 같은폴더에 그림파일 복사
#     3. `hani = np.einsum('ijk->jik',np.array(PIL.Image.open('hani.jpeg'),dtype=np.int64)/255)` 실행
#     4. 그림파일 삭제

# %% [markdown]
# 불러온 이미지는 아래와 같다.

# %%
hani, hani.shape
# Out:
# (array([[[0.44705882, 0.48627451, 0.49411765],
#          [0.43137255, 0.46666667, 0.48627451],
#          [0.45882353, 0.50196078, 0.51764706],
#          ...,
#          [0.6627451 , 0.6627451 , 0.70196078],
#          [0.63529412, 0.62745098, 0.67058824],
#          [0.64313725, 0.63529412, 0.67843137]],
#
#         [[0.45882353, 0.49803922, 0.50588235],
#          [0.44313725, 0.47843137, 0.49803922],
#          [0.4627451 , 0.50588235, 0.52156863],
#          ...,
#          [0.63921569, 0.63921569, 0.67843137],
#          [0.64313725, 0.63529412, 0.67843137],
#          [0.63137255, 0.62352941, 0.66666667]],
#
#         [[0.45490196, 0.49411765, 0.50196078],
#          [0.4627451 , 0.49803922, 0.51764706],
#          [0.45882353, 0.50196078, 0.51764706],
#          ...,
#          [0.64313725, 0.64313725, 0.68235294],
#          [0.65490196, 0.65490196, 0.69411765],
#          [0.64705882, 0.63921569, 0.68235294]],
#
#         ...,
#
#         [[0.69411765, 0.69803922, 0.70588235],
#          [0.68627451, 0.69019608, 0.69803922],
#          [0.69411765, 0.69803922, 0.70588235],
#          ...,
#          [0.60784314, 0.6       , 0.60392157],
#          [0.6       , 0.59215686, 0.59607843],
#          [0.59607843, 0.58823529, 0.59215686]],
#
#         [[0.70196078, 0.70588235, 0.71372549],
#          [0.72156863, 0.7254902 , 0.73333333],
#          [0.69019608, 0.69411765, 0.70196078],
#          ...,
#          [0.61176471, 0.60392157, 0.60784314],
#          [0.60392157, 0.59607843, 0.6       ],
#          [0.61568627, 0.60784314, 0.61176471]],
#
#         [[0.7254902 , 0.72941176, 0.74509804],
#          [0.73333333, 0.7372549 , 0.74509804],
#          [0.70980392, 0.71372549, 0.72156863],
#          ...,
#          [0.61176471, 0.60392157, 0.60784314],
#          [0.60392157, 0.59607843, 0.6       ],
#          [0.61960784, 0.61176471, 0.61568627]]]),
#  (4032, 3024, 3))

# %% [markdown]
# - 이미지는 4032 $\times$ 3024 개의 격자(픽셀)로 이루어져 있음

# %% [markdown]
# 이미지를 보는 방법은 아래와 같다.

# %%
plt.imshow(hani) # 모든이미지, 하니매트릭스

# %%
plt.imshow(hani[1000:1500, 1000:2000,:]) # 얼굴만 확대, 하니의 서브매트릭스

# %% [markdown]
# `3`. 하니이미지를 나타내는 어레이를 변형하여 빨간색을 의미하는 칼라만 남겨서 "빨간하니"를 만들고 이미지를 출력하라.

# %% [markdown]
# (풀이)

# %%
red_hani = hani*0 
red_hani[:,:,0] = hani[:,:,0]

# %%
plt.imshow(red_hani)

# %% [markdown]
# `4`. 하니의 모든 값에 루트를 취하여 "루트하니"를 만들고 "원본하니"와 "루트하니"를 좌우로 나란히 배치하여 출력하라.

# %% [markdown]
# (풀이)

# %%
plt.imshow(np.concatenate([hani, np.sqrt(hani)],axis=1))

# %% [markdown]
# "루트하니"의 이미지는 "원본하니"의 이미지와 비교하여 어떤가? 왜 그러한 결과가 나왔다고 생각하는가?

# %% [markdown]
# `5`. 하니의 모든값에 아래와 같은 함수를 적용하라.

# %% [markdown]
# - $f(x)=\begin{cases} \sqrt{x} & x>0.7 \\ x & x \leq 0.7 \end{cases}$

# %% [markdown]
# 함수의 결과로 얻어진 매트릭스를 "후광하니"라고 부르자. "원본하니"와 "후광하니"를 좌우로 나란히 배치하여 출력하라.

# %% [markdown]
# (풀이)

# %%
shiny_hani = (hani>0.7)*np.sqrt(hani)+(hani<=0.7)*hani
plt.imshow(np.concatenate([hani,shiny_hani],axis=1))
